# %% [markdown]
# #Packages Install and Import

# %%
# !pip install imbalanced-learn
# !pip install --upgrade pandas
# !pip install optuna
# !pip install xgboost
# !pip install python-dotenv
# Out:
# Requirement already satisfied: imbalanced-learn in /Users/yangfei/anaconda3/lib/python3.10/site-packages (0.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from imbalanced-learn) (1.2.1)
# Requirement already satisfied: scipy>=1.3.2 in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from imbalanced-learn) (1.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from imbalanced-learn) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from imbalanced-learn) (1.1.1)
# Requirement already satisfied: numpy>=1.17.3 in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from imbalanced-learn) (1.23.5)
# Requirement already satisfied: pandas in /Users/yangfei/anaconda3/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from pandas) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.22.4 in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: optuna in /Users/yangfei/anaconda3/lib/python3.10/site-packages (3.6.1)
# Requirement already satisfied: alembic>=1.5.0 in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from optuna) (1.13.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from optuna) (1.4.39)
# Requirement already satisfied: colorlog in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from optuna) (6.8.2)
# Requirement already satisfied: tqdm in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from optuna) (4.64.1)
# Requirement already satisfied: PyYAML in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from optuna) (6.0)
# Requirement already satisfied: numpy in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from optuna) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from optuna) (22.0)
# Requirement already satisfied: Mako in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (4.4.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.1)
# Requirement already satisfied: xgboost in /Users/yangfei/anaconda3/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: numpy in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from xgboost) (1.23.5)
# Requirement already satisfied: scipy in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from xgboost) (1.10.0)
# Requirement already satisfied: python-dotenv in /Users/yangfei/anaconda3/lib/python3.10/site-packages (1.0.1)

# %%
import subprocess
import sys

# Upgrade bottleneck package to version 1.3.6 or newer
subprocess.check_call([sys.executable, "-m", "pip", "install", "--upgrade", "bottleneck"])

import pandas as pd
import numpy as np
import os
from dotenv import load_dotenv
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedKFold
from imblearn.over_sampling import SMOTENC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score, make_scorer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
import pickle
import optuna
from xgboost import XGBClassifier

warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: bottleneck in /Users/yangfei/anaconda3/lib/python3.10/site-packages (1.3.8)
# Requirement already satisfied: numpy in /Users/yangfei/anaconda3/lib/python3.10/site-packages (from bottleneck) (1.23.5)

# %%
# Set the option to display all rows or a large number
pd.set_option('display.max_rows', None)  # None means show all rows

# Set the option to display all columns or a large number
pd.set_option('display.max_columns', None)  # None means show all columns

pd.set_option('display.precision', 2)
pd.set_option('display.float_format', '{:.4f}'.format)

# %% [markdown]
# #Load Data and Check Null Values

# %%
# Load Data
dataset = pd.read_csv("zero_div_recent_years.csv")
num_dataset = dataset.select_dtypes(include=[np.number])
# Null value analysis
dataset.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4004 entries, 0 to 4003
# Data columns (total 179 columns):
#  #    Column                                                Non-Null Count  Dtype
# ---   ------                                                --------------  -----
#  0    year                                                  4004 non-null   int64
#  1    adjDividend                                           4004 non-null   float64
#  2    dps_growth                                            4004 non-null   float64
#  3    dps_growth_rate                                       4004 non-null   float64
#  4    industry                                              4004 non-null   object
#  5    sector                                                4004 non-null   object
#  6    companyRating                                         4004 non-null   float64
#  7    companyRating_percentage_change                       4004 non-null   float64
#  8    companyRating_actual_change                           4004 non-null   float64
#  9    interestRate                                          4004 non-null   float64
#  10   interestRate_percentage_change                        4004 non-null   float64
#  11   interestRate_actual_change                            4004 non-null   float64
#  12   inflationRate                                         4004 non-null   float64
#  13   inflationRate_percentage_change                       4004 non-null   float64
#  14   inflationRate_actual_change                           4004 non-null   float64
#  15   symbol                                                4004 non-null   object
#  16   currentRatio                                          4004 non-null   float64
#  17   currentRatio_percentage_change                        4004 non-null   float64
#  18   currentRatio_actual_change                            4004 non-null   float64
#  19   quickRatio                                            4004 non-null   float64
#  20   quickRatio_percentage_change                          4004 non-null   float64
#  21   quickRatio_actual_change                              4004 non-null   float64
#  22   cashRatio                                             4004 non-null   float64
#  23   cashRatio_percentage_change                           4004 non-null   float64
#  24   cashRatio_actual_change                               4004 non-null   float64
#  25   daysOfSalesOutstanding                                4004 non-null   float64
#  26   daysOfSalesOutstanding_percentage_change              4004 non-null   float64
#  27   daysOfSalesOutstanding_actual_change                  4004 non-null   float64
#  28   daysOfInventoryOutstanding                            4004 non-null   float64
#  29   daysOfInventoryOutstanding_percentage_change          4004 non-null   float64
#  30   daysOfInventoryOutstanding_actual_change              4004 non-null   float64
#  31   operatingCycle                                        4004 non-null   float64
#  32   operatingCycle_percentage_change                      4004 non-null   float64
#  33   operatingCycle_actual_change                          4004 non-null   float64
#  34   daysOfPayablesOutstanding                             4004 non-null   float64
#  35   daysOfPayablesOutstanding_percentage_change           4004 non-null   float64
#  36   daysOfPayablesOutstanding_actual_change               4004 non-null   float64
#  37   cashConversionCycle                                   4004 non-null   float64
#  38   cashConversionCycle_percentage_change                 4004 non-null   float64
#  39   cashConversionCycle_actual_change                     4004 non-null   float64
#  40   grossProfitMargin                                     4004 non-null   float64
#  41   grossProfitMargin_percentage_change                   4004 non-null   float64
#  42   grossProfitMargin_actual_change                       4004 non-null   float64
#  43   operatingProfitMargin                                 4004 non-null   float64
#  44   operatingProfitMargin_percentage_change               4004 non-null   float64
#  45   operatingProfitMargin_actual_change                   4004 non-null   float64
#  46   pretaxProfitMargin                                    4004 non-null   float64
#  47   pretaxProfitMargin_percentage_change                  4004 non-null   float64
#  48   pretaxProfitMargin_actual_change                      4004 non-null   float64
#  49   netProfitMargin                                       4004 non-null   float64
#  50   netProfitMargin_percentage_change                     4004 non-null   float64
#  51   netProfitMargin_actual_change                         4004 non-null   float64
#  52   effectiveTaxRate                                      4004 non-null   float64
#  53   effectiveTaxRate_percentage_change                    4004 non-null   float64
#  54   effectiveTaxRate_actual_change                        4004 non-null   float64
#  55   returnOnAssets                                        4004 non-null   float64
#  56   returnOnAssets_percentage_change                      4004 non-null   float64
#  57   returnOnAssets_actual_change                          4004 non-null   float64
#  58   returnOnEquity                                        4004 non-null   float64
#  59   returnOnEquity_percentage_change                      4004 non-null   float64
#  60   returnOnEquity_actual_change                          4004 non-null   float64
#  61   returnOnCapitalEmployed                               4004 non-null   float64
#  62   returnOnCapitalEmployed_percentage_change             4004 non-null   float64
#  63   returnOnCapitalEmployed_actual_change                 4004 non-null   float64
#  64   netIncomePerEBT                                       4004 non-null   float64
#  65   netIncomePerEBT_percentage_change                     4004 non-null   float64
#  66   netIncomePerEBT_actual_change                         4004 non-null   float64
#  67   ebtPerEbit                                            4004 non-null   float64
#  68   ebtPerEbit_percentage_change                          4004 non-null   float64
#  69   ebtPerEbit_actual_change                              4004 non-null   float64
#  70   ebitPerRevenue                                        4004 non-null   float64
#  71   ebitPerRevenue_percentage_change                      4004 non-null   float64
#  72   ebitPerRevenue_actual_change                          4004 non-null   float64
#  73   debtRatio                                             4004 non-null   float64
#  74   debtRatio_percentage_change                           4004 non-null   float64
#  75   debtRatio_actual_change                               4004 non-null   float64
#  76   debtEquityRatio                                       4004 non-null   float64
#  77   debtEquityRatio_percentage_change                     4004 non-null   float64
#  78   debtEquityRatio_actual_change                         4004 non-null   float64
#  79   longTermDebtToCapitalization                          4004 non-null   float64
#  80   longTermDebtToCapitalization_percentage_change        4004 non-null   float64
#  81   longTermDebtToCapitalization_actual_change            4004 non-null   float64
#  82   totalDebtToCapitalization                             4004 non-null   float64
#  83   totalDebtToCapitalization_percentage_change           4004 non-null   float64
#  84   totalDebtToCapitalization_actual_change               4004 non-null   float64
#  85   interestCoverage                                      4004 non-null   float64
#  86   interestCoverage_percentage_change                    4004 non-null   float64
#  87   interestCoverage_actual_change                        4004 non-null   float64
#  88   cashFlowToDebtRatio                                   4004 non-null   float64
#  89   cashFlowToDebtRatio_percentage_change                 4004 non-null   float64
#  90   cashFlowToDebtRatio_actual_change                     4004 non-null   float64
#  91   companyEquityMultiplier                               4004 non-null   float64
#  92   companyEquityMultiplier_percentage_change             4004 non-null   float64
#  93   companyEquityMultiplier_actual_change                 4004 non-null   float64
#  94   receivablesTurnover                                   4004 non-null   float64
#  95   receivablesTurnover_percentage_change                 4004 non-null   float64
#  96   receivablesTurnover_actual_change                     4004 non-null   float64
#  97   payablesTurnover                                      4004 non-null   float64
#  98   payablesTurnover_percentage_change                    4004 non-null   float64
#  99   payablesTurnover_actual_change                        4004 non-null   float64
#  100  inventoryTurnover                                     4004 non-null   float64
#  101  inventoryTurnover_percentage_change                   4004 non-null   float64
#  102  inventoryTurnover_actual_change                       4004 non-null   float64
#  103  fixedAssetTurnover                                    4004 non-null   float64
#  104  fixedAssetTurnover_percentage_change                  4004 non-null   float64
#  105  fixedAssetTurnover_actual_change                      4004 non-null   float64
#  106  assetTurnover                                         4004 non-null   float64
#  107  assetTurnover_percentage_change                       4004 non-null   float64
#  108  assetTurnover_actual_change                           4004 non-null   float64
#  109  operatingCashFlowPerShare                             4004 non-null   float64
#  110  operatingCashFlowPerShare_percentage_change           4004 non-null   float64
#  111  operatingCashFlowPerShare_actual_change               4004 non-null   float64
#  112  freeCashFlowPerShare                                  4004 non-null   float64
#  113  freeCashFlowPerShare_percentage_change                4004 non-null   float64
#  114  freeCashFlowPerShare_actual_change                    4004 non-null   float64
#  115  cashPerShare                                          4004 non-null   float64
#  116  cashPerShare_percentage_change                        4004 non-null   float64
#  117  cashPerShare_actual_change                            4004 non-null   float64
#  118  payoutRatio                                           4004 non-null   float64
#  119  payoutRatio_percentage_change                         4004 non-null   float64
#  120  payoutRatio_actual_change                             4004 non-null   float64
#  121  operatingCashFlowSalesRatio                           4004 non-null   float64
#  122  operatingCashFlowSalesRatio_percentage_change         4004 non-null   float64
#  123  operatingCashFlowSalesRatio_actual_change             4004 non-null   float64
#  124  freeCashFlowOperatingCashFlowRatio                    4004 non-null   float64
#  125  freeCashFlowOperatingCashFlowRatio_percentage_change  4004 non-null   float64
#  126  freeCashFlowOperatingCashFlowRatio_actual_change      4004 non-null   float64
#  127  cashFlowCoverageRatios                                4004 non-null   float64
#  128  cashFlowCoverageRatios_percentage_change              4004 non-null   float64
#  129  cashFlowCoverageRatios_actual_change                  4004 non-null   float64
#  130  shortTermCoverageRatios                               4004 non-null   float64
#  131  shortTermCoverageRatios_percentage_change             4004 non-null   float64
#  132  shortTermCoverageRatios_actual_change                 4004 non-null   float64
#  133  capitalExpenditureCoverageRatio                       4004 non-null   float64
#  134  capitalExpenditureCoverageRatio_percentage_change     4004 non-null   float64
#  135  capitalExpenditureCoverageRatio_actual_change         4004 non-null   float64
#  136  dividendPaidAndCapexCoverageRatio                     4004 non-null   float64
#  137  dividendPaidAndCapexCoverageRatio_percentage_change   4004 non-null   float64
#  138  dividendPaidAndCapexCoverageRatio_actual_change       4004 non-null   float64
#  139  dividendPayoutRatio                                   4004 non-null   float64
#  140  dividendPayoutRatio_percentage_change                 4004 non-null   float64
#  141  dividendPayoutRatio_actual_change                     4004 non-null   float64
#  142  priceBookValueRatio                                   4004 non-null   float64
#  143  priceBookValueRatio_percentage_change                 4004 non-null   float64
#  144  priceBookValueRatio_actual_change                     4004 non-null   float64
#  145  priceToBookRatio                                      4004 non-null   float64
#  146  priceToBookRatio_percentage_change                    4004 non-null   float64
#  147  priceToBookRatio_actual_change                        4004 non-null   float64
#  148  priceToSalesRatio                                     4004 non-null   float64
#  149  priceToSalesRatio_percentage_change                   4004 non-null   float64
#  150  priceToSalesRatio_actual_change                       4004 non-null   float64
#  151  priceEarningsRatio                                    4004 non-null   float64
#  152  priceEarningsRatio_percentage_change                  4004 non-null   float64
#  153  priceEarningsRatio_actual_change                      4004 non-null   float64
#  154  priceToFreeCashFlowsRatio                             4004 non-null   float64
#  155  priceToFreeCashFlowsRatio_percentage_change           4004 non-null   float64
#  156  priceToFreeCashFlowsRatio_actual_change               4004 non-null   float64
#  157  priceToOperatingCashFlowsRatio                        4004 non-null   float64
#  158  priceToOperatingCashFlowsRatio_percentage_change      4004 non-null   float64
#  159  priceToOperatingCashFlowsRatio_actual_change          4004 non-null   float64
#  160  priceCashFlowRatio                                    4004 non-null   float64
#  161  priceCashFlowRatio_percentage_change                  4004 non-null   float64
#  162  priceCashFlowRatio_actual_change                      4004 non-null   float64
#  163  priceEarningsToGrowthRatio                            4004 non-null   float64
#  164  priceEarningsToGrowthRatio_percentage_change          4004 non-null   float64
#  165  priceEarningsToGrowthRatio_actual_change              4004 non-null   float64
#  166  priceSalesRatio                                       4004 non-null   float64
#  167  priceSalesRatio_percentage_change                     4004 non-null   float64
#  168  priceSalesRatio_actual_change                         4004 non-null   float64
#  169  dividendYield                                         4004 non-null   float64
#  170  dividendYield_percentage_change                       4004 non-null   float64
#  171  dividendYield_actual_change                           4004 non-null   float64
#  172  enterpriseValueMultiple                               4004 non-null   float64
#  173  enterpriseValueMultiple_percentage_change             4004 non-null   float64
#  174  enterpriseValueMultiple_actual_change                 4004 non-null   float64
#  175  priceFairValue                                        4004 non-null   float64
#  176  priceFairValue_percentage_change                      4004 non-null   float64
#  177  priceFairValue_actual_change                          4004 non-null   float64
#  178  dps_change_next_year                                  4004 non-null   object
# dtypes: float64(174), int64(1), object(4)
# memory usage: 5.5+ MB

# %% [markdown]
# #Multivariate Analysis

# %%
# Correlation matrix
correlation_matrix = num_dataset.corr()

def rank_columns_by_correlation(df, threshold):
    # Calculating correlation matrix
    corr_matrix = df.corr()
    # Initializing a list to hold the tuples (col1, col2, correlation)
    correlations = []
    # Iterating over the correlation matrix
    for i in range(len(corr_matrix.columns)):
        for j in range(i + 1, len(corr_matrix.columns)):  # avoiding duplicate and self-correlation
            # Including only correlations above the specified threshold
            if abs(corr_matrix.iloc[i, j]) > threshold:
                correlations.append((corr_matrix.columns[i], corr_matrix.columns[j], corr_matrix.iloc[i, j]))

    # Sorting the list by absolute correlation in descending order
    sorted_correlations = sorted(correlations, key=lambda x: abs(x[2]), reverse=True)
    correlation_df = pd.DataFrame(sorted_correlations, columns=['Column1', 'Column2', 'Correlation'])
    return correlation_df

top_correlations = rank_columns_by_correlation(num_dataset, 0.9)

# Remove highly correlated columns
columns_to_remove = top_correlations["Column2"].unique()
dataset.drop(columns_to_remove, axis="columns", inplace=True)

# %% [markdown]
# #Train-Test Split

# %%
# Data Separation by Year
training_data = dataset.loc[dataset["year"] < 2021]
testing_data = dataset[(dataset['year'] == 2021) | (dataset['year'] == 2022)]


# Predictor - Target Split
X_train = training_data.drop("dps_change_next_year", axis="columns")
y_train = training_data["dps_change_next_year"]
X_test = testing_data.drop("dps_change_next_year", axis="columns")
y_test = testing_data["dps_change_next_year"]

# %% [markdown]
# #Data Pre-Processing, Encode Categorical Features, Normalize Feature Values

# %%
# Define categorical and other columns
categorical_columns = ["industry", "sector", "symbol"]
other_columns = [col for col in X_train.columns if col not in categorical_columns]

# Preprocessing: Label encoding and Scaling
column_transformer = ColumnTransformer(
    transformers=[
        ('categorical', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), categorical_columns)
    ],
    remainder='passthrough'
)

# Standard scaling within a pipeline to prevent data leakage
pipeline_preprocess = Pipeline([
    ('transformer', column_transformer),
    ('scaler', StandardScaler())
])

X_train_transformed = pipeline_preprocess.fit_transform(X_train)
X_test_transformed = pipeline_preprocess.transform(X_test)

# Note: after transformation, the output will be a numpy array and column orders will be changed.
X_train_transformed = pd.DataFrame(X_train_transformed, columns=categorical_columns + other_columns)
X_test_transformed = pd.DataFrame(X_test_transformed, columns=categorical_columns + other_columns)

# Check our data type
X_train_transformed.info(verbose=True, show_counts=True)

# Let's change our data types back to their original forms - However, this time, categorical variables have become
# number like strings
cols_to_convert = {'industry': 'str', 'sector': 'str', 'symbol': 'str', 'year': 'int'}
X_train_transformed = X_train_transformed.astype(cols_to_convert)
X_test_transformed = X_test_transformed.astype(cols_to_convert)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 116 columns):
#  #    Column                                                Non-Null Count  Dtype
# ---   ------                                                --------------  -----
#  0    industry                                              3276 non-null   float64
#  1    sector                                                3276 non-null   float64
#  2    symbol                                                3276 non-null   float64
#  3    year                                                  3276 non-null   float64
#  4    adjDividend                                           3276 non-null   float64
#  5    dps_growth                                            3276 non-null   float64
#  6    dps_growth_rate                                       3276 non-null   float64
#  7    companyRating                                         3276 non-null   float64
#  8    companyRating_percentage_change                       3276 non-null   float64
#  9    companyRating_actual_change                           3276 non-null   float64
#  10   interestRate                                          3276 non-null   float64
#  11   interestRate_percentage_change                        3276 non-null   float64
#  12   interestRate_actual_change                            3276 non-null   float64
#  13   inflationRate_percentage_change                       3276 non-null   float64
#  14   currentRatio                                          3276 non-null   float64
#  15   currentRatio_percentage_change                        3276 non-null   float64
#  16   currentRatio_actual_change                            3276 non-null   float64
#  17   quickRatio                                            3276 non-null   float64
#  18   quickRatio_actual_change                              3276 non-null   float64
#  19   daysOfSalesOutstanding                                3276 non-null   float64
#  20   daysOfSalesOutstanding_percentage_change              3276 non-null   float64
#  21   daysOfSalesOutstanding_actual_change                  3276 non-null   float64
#  22   daysOfInventoryOutstanding                            3276 non-null   float64
#  23   daysOfInventoryOutstanding_percentage_change          3276 non-null   float64
#  24   daysOfInventoryOutstanding_actual_change              3276 non-null   float64
#  25   operatingCycle_percentage_change                      3276 non-null   float64
#  26   grossProfitMargin                                     3276 non-null   float64
#  27   grossProfitMargin_percentage_change                   3276 non-null   float64
#  28   grossProfitMargin_actual_change                       3276 non-null   float64
#  29   operatingProfitMargin                                 3276 non-null   float64
#  30   operatingProfitMargin_percentage_change               3276 non-null   float64
#  31   operatingProfitMargin_actual_change                   3276 non-null   float64
#  32   pretaxProfitMargin                                    3276 non-null   float64
#  33   pretaxProfitMargin_percentage_change                  3276 non-null   float64
#  34   pretaxProfitMargin_actual_change                      3276 non-null   float64
#  35   netProfitMargin_percentage_change                     3276 non-null   float64
#  36   effectiveTaxRate                                      3276 non-null   float64
#  37   returnOnAssets                                        3276 non-null   float64
#  38   returnOnAssets_actual_change                          3276 non-null   float64
#  39   returnOnEquity                                        3276 non-null   float64
#  40   returnOnEquity_percentage_change                      3276 non-null   float64
#  41   returnOnEquity_actual_change                          3276 non-null   float64
#  42   returnOnCapitalEmployed                               3276 non-null   float64
#  43   returnOnCapitalEmployed_actual_change                 3276 non-null   float64
#  44   netIncomePerEBT                                       3276 non-null   float64
#  45   netIncomePerEBT_percentage_change                     3276 non-null   float64
#  46   netIncomePerEBT_actual_change                         3276 non-null   float64
#  47   ebtPerEbit                                            3276 non-null   float64
#  48   ebtPerEbit_percentage_change                          3276 non-null   float64
#  49   debtRatio                                             3276 non-null   float64
#  50   debtRatio_percentage_change                           3276 non-null   float64
#  51   debtRatio_actual_change                               3276 non-null   float64
#  52   debtEquityRatio                                       3276 non-null   float64
#  53   debtEquityRatio_actual_change                         3276 non-null   float64
#  54   longTermDebtToCapitalization                          3276 non-null   float64
#  55   longTermDebtToCapitalization_percentage_change        3276 non-null   float64
#  56   longTermDebtToCapitalization_actual_change            3276 non-null   float64
#  57   totalDebtToCapitalization_actual_change               3276 non-null   float64
#  58   interestCoverage                                      3276 non-null   float64
#  59   interestCoverage_actual_change                        3276 non-null   float64
#  60   cashFlowToDebtRatio                                   3276 non-null   float64
#  61   cashFlowToDebtRatio_percentage_change                 3276 non-null   float64
#  62   companyEquityMultiplier                               3276 non-null   float64
#  63   companyEquityMultiplier_percentage_change             3276 non-null   float64
#  64   companyEquityMultiplier_actual_change                 3276 non-null   float64
#  65   receivablesTurnover                                   3276 non-null   float64
#  66   receivablesTurnover_percentage_change                 3276 non-null   float64
#  67   receivablesTurnover_actual_change                     3276 non-null   float64
#  68   payablesTurnover                                      3276 non-null   float64
#  69   payablesTurnover_percentage_change                    3276 non-null   float64
#  70   payablesTurnover_actual_change                        3276 non-null   float64
#  71   inventoryTurnover                                     3276 non-null   float64
#  72   inventoryTurnover_percentage_change                   3276 non-null   float64
#  73   inventoryTurnover_actual_change                       3276 non-null   float64
#  74   fixedAssetTurnover                                    3276 non-null   float64
#  75   fixedAssetTurnover_percentage_change                  3276 non-null   float64
#  76   fixedAssetTurnover_actual_change                      3276 non-null   float64
#  77   assetTurnover                                         3276 non-null   float64
#  78   assetTurnover_percentage_change                       3276 non-null   float64
#  79   assetTurnover_actual_change                           3276 non-null   float64
#  80   operatingCashFlowPerShare                             3276 non-null   float64
#  81   operatingCashFlowPerShare_actual_change               3276 non-null   float64
#  82   freeCashFlowPerShare                                  3276 non-null   float64
#  83   freeCashFlowPerShare_percentage_change                3276 non-null   float64
#  84   freeCashFlowPerShare_actual_change                    3276 non-null   float64
#  85   cashPerShare                                          3276 non-null   float64
#  86   cashPerShare_percentage_change                        3276 non-null   float64
#  87   cashPerShare_actual_change                            3276 non-null   float64
#  88   operatingCashFlowSalesRatio                           3276 non-null   float64
#  89   operatingCashFlowSalesRatio_actual_change             3276 non-null   float64
#  90   freeCashFlowOperatingCashFlowRatio                    3276 non-null   float64
#  91   freeCashFlowOperatingCashFlowRatio_percentage_change  3276 non-null   float64
#  92   freeCashFlowOperatingCashFlowRatio_actual_change      3276 non-null   float64
#  93   shortTermCoverageRatios                               3276 non-null   float64
#  94   shortTermCoverageRatios_percentage_change             3276 non-null   float64
#  95   shortTermCoverageRatios_actual_change                 3276 non-null   float64
#  96   capitalExpenditureCoverageRatio                       3276 non-null   float64
#  97   capitalExpenditureCoverageRatio_percentage_change     3276 non-null   float64
#  98   capitalExpenditureCoverageRatio_actual_change         3276 non-null   float64
#  99   dividendPaidAndCapexCoverageRatio                     3276 non-null   float64
#  100  dividendPaidAndCapexCoverageRatio_percentage_change   3276 non-null   float64
#  101  dividendPaidAndCapexCoverageRatio_actual_change       3276 non-null   float64
#  102  priceToSalesRatio                                     3276 non-null   float64
#  103  priceToSalesRatio_percentage_change                   3276 non-null   float64
#  104  priceToSalesRatio_actual_change                       3276 non-null   float64
#  105  priceToFreeCashFlowsRatio                             3276 non-null   float64
#  106  priceToFreeCashFlowsRatio_percentage_change           3276 non-null   float64
#  107  priceToFreeCashFlowsRatio_actual_change               3276 non-null   float64
#  108  priceToOperatingCashFlowsRatio                        3276 non-null   float64
#  109  priceToOperatingCashFlowsRatio_percentage_change      3276 non-null   float64
#  110  priceToOperatingCashFlowsRatio_actual_change          3276 non-null   float64
#  111  priceEarningsToGrowthRatio_percentage_change          3276 non-null   float64
#  112  dividendYield                                         3276 non-null   float64
#  113  dividendYield_percentage_change                       3276 non-null   float64
#  114  dividendYield_actual_change                           3276 non-null   float64
#  115  enterpriseValueMultiple                               3276 non-null   float64
# dtypes: float64(116)
# memory usage: 2.9 MB

# %% [markdown]
# #Check Data Imbalanced

# %%
training_data_transformed = pd.concat([X_train_transformed, y_train], axis=1)
training_data_transformed["dps_change_next_year"].value_counts()
# Out:
# dps_change_next_year
# constant/increased    3105
# decreased              171
# Name: count, dtype: int64

# %% [markdown]
# #Stratified Cross-Validation and Smote Oversampling

# %%
# Stratified Cross-Validation Setup
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
# Perform oversampling using SMOTE
categorical_indices = [X_train_transformed.columns.get_loc(col) for col in categorical_columns]
smote = SMOTENC(random_state=1, categorical_features=categorical_indices)
X_train_oversampled, y_train_oversampled = smote.fit_resample(X_train_transformed, y_train)
# Check our training data
pd.DataFrame(y_train_oversampled)["dps_change_next_year"].value_counts()
X_train_oversampled.info()
y_train_oversampled.value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6210 entries, 0 to 6209
# Columns: 116 entries, industry to enterpriseValueMultiple
# dtypes: float64(112), int64(1), object(3)
# memory usage: 5.5+ MB
# dps_change_next_year
# constant/increased    3105
# decreased             3105
# Name: count, dtype: int64

# %% [markdown]
# #Feature Selection

# %%
# Feature importance analysis - Tree Based
randomForestModel = RandomForestClassifier(max_features=None)  # We want all features to be considered for each tree
randomForestModel.fit(X_train_oversampled, y_train_oversampled)
model_importance = randomForestModel.feature_importances_
importance_table = pd.DataFrame(columns=["Feature", "Importance"])  # Create an importance table to plot bar chart
featureNum = 0
for score in model_importance:
    print("feature " + str(featureNum) + "'s importance score: " + str(score) + " (" + X_train_oversampled.columns[featureNum] + ")")
    rowAdded = pd.DataFrame([[X_train_oversampled.columns[featureNum], score]], columns=["Feature", "Importance"])
    importance_table = pd.concat([importance_table, rowAdded])
    featureNum = featureNum + 1
importance_table.sort_values('Importance', inplace=True, ascending=False)


# Plot a bar chart to visualize feature importance
plt.figure(figsize=(20, 10))
sns.barplot(data=importance_table, x="Feature", y="Importance")
plt.title("Feature Importance")
plt.subplots_adjust(bottom=0.2, top=0.95)
plt.xticks(rotation=45, ha='right', rotation_mode="anchor")
plt.savefig('feature.png')
plt.show()
# Out:
# feature 0's importance score: 0.005596457963901076 (industry)
# feature 1's importance score: 0.004109882527192174 (sector)
# feature 2's importance score: 0.019612964062440293 (symbol)
# feature 3's importance score: 0.002683237213959199 (year)
# feature 4's importance score: 0.021987216946713836 (adjDividend)
# feature 5's importance score: 0.055366954029332914 (dps_growth)
# feature 6's importance score: 0.10509952909389618 (dps_growth_rate)
# feature 7's importance score: 0.03890581361352838 (companyRating)
# feature 8's importance score: 0.010757411771366587 (companyRating_percentage_change)
# feature 9's importance score: 0.06001140563859935 (companyRating_actual_change)
# feature 10's importance score: 0.01757778050016946 (interestRate)
# feature 11's importance score: 0.006924624385045582 (interestRate_percentage_change)
# feature 12's importance score: 0.013345696088338396 (interestRate_actual_change)
# feature 13's importance score: 0.007778614801892445 (inflationRate_percentage_change)
# feature 14's importance score: 0.0048435353892743414 (currentRatio)
# feature 15's importance score: 0.0032348317459205116 (currentRatio_percentage_change)
# feature 16's importance score: 0.0019437601864966654 (currentRatio_actual_change)
# feature 17's importance score: 0.00890769847445148 (quickRatio)
# feature 18's importance score: 0.001989171908282712 (quickRatio_actual_change)
# feature 19's importance score: 0.008113520142116437 (daysOfSalesOutstanding)
# feature 20's importance score: 0.0011538146496869101 (daysOfSalesOutstanding_percentage_change)
# feature 21's importance score: 0.0023497631961658548 (daysOfSalesOutstanding_actual_change)
# feature 22's importance score: 0.004209563897938699 (daysOfInventoryOutstanding)
# feature 23's importance score: 0.00019389539467685692 (daysOfInventoryOutstanding_percentage_change)
# feature 24's importance score: 0.00865195195264091 (daysOfInventoryOutstanding_actual_change)
# feature 25's importance score: 0.006834397013309686 (operatingCycle_percentage_change)
# feature 26's importance score: 0.007903646275595344 (grossProfitMargin)
# feature 27's importance score: 0.0027558442820975466 (grossProfitMargin_percentage_change)
# feature 28's importance score: 0.002620859171185819 (grossProfitMargin_actual_change)
# feature 29's importance score: 0.004133014392295439 (operatingProfitMargin)
# feature 30's importance score: 0.004315307425346109 (operatingProfitMargin_percentage_change)
# feature 31's importance score: 0.002933631806747026 (operatingProfitMargin_actual_change)
# feature 32's importance score: 0.01509789573895539 (pretaxProfitMargin)
# feature 33's importance score: 0.0028541436647168427 (pretaxProfitMargin_percentage_change)
# feature 34's importance score: 0.0045521473537521555 (pretaxProfitMargin_actual_change)
# feature 35's importance score: 0.003236168394903046 (netProfitMargin_percentage_change)
# feature 36's importance score: 0.0027131380732333633 (effectiveTaxRate)
# feature 37's importance score: 0.002793169748535242 (returnOnAssets)
# feature 38's importance score: 0.002893236428813538 (returnOnAssets_actual_change)
# feature 39's importance score: 0.00719332229443428 (returnOnEquity)
# feature 40's importance score: 0.0018578375675274267 (returnOnEquity_percentage_change)
# feature 41's importance score: 0.0024810310657504045 (returnOnEquity_actual_change)
# feature 42's importance score: 0.0064251238454034534 (returnOnCapitalEmployed)
# feature 43's importance score: 0.0026823837128108364 (returnOnCapitalEmployed_actual_change)
# feature 44's importance score: 0.003221266055754116 (netIncomePerEBT)
# feature 45's importance score: 0.005848328251815895 (netIncomePerEBT_percentage_change)
# feature 46's importance score: 0.002642239311193165 (netIncomePerEBT_actual_change)
# feature 47's importance score: 0.0025534928633204734 (ebtPerEbit)
# feature 48's importance score: 0.003663782820578043 (ebtPerEbit_percentage_change)
# feature 49's importance score: 0.004101825516788889 (debtRatio)
# feature 50's importance score: 0.003760329216317076 (debtRatio_percentage_change)
# feature 51's importance score: 0.00428505548086359 (debtRatio_actual_change)
# feature 52's importance score: 0.0028112716727859157 (debtEquityRatio)
# feature 53's importance score: 0.002266133621433801 (debtEquityRatio_actual_change)
# feature 54's importance score: 0.010458043050652786 (longTermDebtToCapitalization)
# feature 55's importance score: 0.0026456659323890303 (longTermDebtToCapitalization_percentage_change)
# feature 56's importance score: 0.0030056426717545172 (longTermDebtToCapitalization_actual_change)
# feature 99's importance score: 0.005138767156992499 (dividendPaidAndCapexCoverageRatio)
# feature 100's importance score: 0.007070863069940854 (dividendPaidAndCapexCoverageRatio_percentage_change)
# feature 101's importance score: 0.006306436676751145 (dividendPaidAndCapexCoverageRatio_actual_change)
# feature 102's importance score: 0.00856792193789953 (priceToSalesRatio)
# feature 103's importance score: 0.003156783984446465 (priceToSalesRatio_percentage_change)
# feature 104's importance score: 0.005068809997958145 (priceToSalesRatio_actual_change)
# feature 105's importance score: 0.005052961733325898 (priceToFreeCashFlowsRatio)
# feature 106's importance score: 0.0059535740979957345 (priceToFreeCashFlowsRatio_percentage_change)
# feature 107's importance score: 0.003138820895469398 (priceToFreeCashFlowsRatio_actual_change)
# feature 108's importance score: 0.0038113608753129542 (priceToOperatingCashFlowsRatio)
# feature 109's importance score: 0.00317879548747961 (priceToOperatingCashFlowsRatio_percentage_change)
# feature 110's importance score: 0.00451449589746775 (priceToOperatingCashFlowsRatio_actual_change)
# feature 111's importance score: 0.007348076531768649 (priceEarningsToGrowthRatio_percentage_change)
# feature 112's importance score: 0.18670795418193445 (dividendYield)
# feature 113's importance score: 0.011867806754546977 (dividendYield_percentage_change)
# feature 114's importance score: 0.004712302370233184 (dividendYield_actual_change)
# feature 115's importance score: 0.006149266341371624 (enterpriseValueMultiple)

# %%
# Sort features by importance in descending order
importance_table.sort_values(by='Importance', ascending=False, inplace=True)

# Calculate cumulative importance
importance_table['Cumulative Importance'] = importance_table['Importance'].cumsum()

# Find the last acceptable feature (where cumulative importance is just at or above 60%)
cutoff_index = importance_table[importance_table['Cumulative Importance'] <= 0.60].last_valid_index()

# If there is no such index, adjust the percentage criteria or take all features
if cutoff_index is None:
    selected_features = importance_table['Feature'].tolist()
else:
    selected_features = importance_table.loc[:cutoff_index, 'Feature'].tolist()

# Selected features are those that contribute to the top 60% of importance scores
print("Selected Features:", selected_features)
# Out:
# Selected Features: ['dividendYield', 'dps_growth_rate', 'companyRating_actual_change', 'dps_growth', 'companyRating', 'adjDividend', 'symbol', 'interestRate', 'payablesTurnover', 'interestRate_actual_change', 'dividendYield_percentage_change', 'pretaxProfitMargin', 'longTermDebtToCapitalization', 'companyRating_percentage_change', 'grossProfitMargin', 'operatingCashFlowPerShare', 'priceToSalesRatio', 'freeCashFlowPerShare', 'inflationRate_percentage_change', 'quickRatio', 'returnOnEquity', 'daysOfSalesOutstanding', 'operatingCycle_percentage_change', 'daysOfInventoryOutstanding_actual_change', 'operatingCashFlowSalesRatio', 'interestRate_percentage_change', 'priceEarningsToGrowthRatio_percentage_change', 'dividendPaidAndCapexCoverageRatio_percentage_change', 'enterpriseValueMultiple', 'assetTurnover', 'fixedAssetTurnover', 'companyEquityMultiplier', 'capitalExpenditureCoverageRatio_actual_change', 'industry', 'dividendPaidAndCapexCoverageRatio_actual_change', 'priceToFreeCashFlowsRatio_percentage_change', 'cashPerShare', 'pretaxProfitMargin_actual_change', 'fixedAssetTurnover_actual_change', 'priceToOperatingCashFlowsRatio_actual_change', 'shortTermCoverageRatios_actual_change', 'dividendPaidAndCapexCoverageRatio', 'capitalExpenditureCoverageRatio', 'interestCoverage_actual_change', 'returnOnCapitalEmployed', 'daysOfInventoryOutstanding', 'priceToFreeCashFlowsRatio', 'operatingProfitMargin', 'netIncomePerEBT_percentage_change', 'receivablesTurnover_actual_change', 'freeCashFlowOperatingCashFlowRatio_percentage_change', 'debtRatio_percentage_change', 'currentRatio', 'freeCashFlowOperatingCashFlowRatio', 'shortTermCoverageRatios_percentage_change', 'cashPerShare_percentage_change', 'shortTermCoverageRatios', 'priceToSalesRatio_actual_change', 'ebtPerEbit_percentage_change', 'payablesTurnover_actual_change', 'returnOnAssets_actual_change', 'dividendYield_actual_change', 'sector', 'netIncomePerEBT', 'companyEquityMultiplier_actual_change', 'payablesTurnover_percentage_change', 'priceToOperatingCashFlowsRatio', 'assetTurnover_actual_change', 'operatingProfitMargin_percentage_change', 'netIncomePerEBT_actual_change', 'operatingProfitMargin_actual_change', 'debtRatio', 'longTermDebtToCapitalization_percentage_change', 'debtEquityRatio_actual_change', 'currentRatio_percentage_change', 'priceToSalesRatio_percentage_change', 'returnOnAssets', 'grossProfitMargin_percentage_change', 'debtEquityRatio', 'cashFlowToDebtRatio', 'debtRatio_actual_change', 'receivablesTurnover', 'effectiveTaxRate', 'companyEquityMultiplier_percentage_change', 'longTermDebtToCapitalization_actual_change', 'daysOfSalesOutstanding_actual_change', 'priceToOperatingCashFlowsRatio_percentage_change', 'ebtPerEbit', 'priceToFreeCashFlowsRatio_actual_change', 'cashPerShare_actual_change', 'freeCashFlowPerShare_percentage_change', 'returnOnEquity_actual_change', 'returnOnCapitalEmployed_actual_change', 'fixedAssetTurnover_percentage_change', 'freeCashFlowPerShare_actual_change', 'assetTurnover_percentage_change', 'totalDebtToCapitalization_actual_change', 'cashFlowToDebtRatio_percentage_change', 'interestCoverage', 'operatingCashFlowPerShare_actual_change', 'freeCashFlowOperatingCashFlowRatio_actual_change', 'grossProfitMargin_actual_change', 'netProfitMargin_percentage_change', 'currentRatio_actual_change', 'pretaxProfitMargin_percentage_change', 'year', 'operatingCashFlowSalesRatio_actual_change', 'quickRatio_actual_change', 'receivablesTurnover_percentage_change', 'capitalExpenditureCoverageRatio_percentage_change', 'returnOnEquity_percentage_change', 'daysOfSalesOutstanding_percentage_change', 'inventoryTurnover_actual_change', 'inventoryTurnover', 'inventoryTurnover_percentage_change', 'daysOfInventoryOutstanding_percentage_change']

# %% [markdown]
# #Feature Engineering(PCA)

# %%
X_train_oversampled = X_train_oversampled[selected_features]
X_test_transformed = X_test_transformed[selected_features]

# Applying PCA function on training
# and testing set of X component
from sklearn.decomposition import PCA

pca = PCA().fit(X_train_oversampled)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')

pca = PCA(n_components = 0.95)

X_train_final = pca.fit_transform(X_train_oversampled)
X_test_final = pca.transform(X_test_transformed)

explained_variance = pca.explained_variance_ratio_

# %% [markdown]
# #Model Training

# %% [markdown]
# ##Logistic Regression

# %%
# Simulate best_params_lr
best_params_lr = {"C": 1.0, "penalty": "l2"}

#Create and save model
best_model_lr = LogisticRegression(**best_params_lr, solver='liblinear', n_jobs=-1)

# Define the directory and file path to save the model
model_dir = 'best_models'
model_file = os.path.join(model_dir, 'lr.pkl')

# If the directory does not exist, create the directory
os.makedirs(model_dir, exist_ok=True)

# Save model
with open(model_file, 'wb') as file:
     pickle.dump(best_model_lr, file)

# %%
# Simulate best_params_lr
best_params_lr = {"C": 1.0, "penalty": "l2"}

#Create and save model
best_model_lr = LogisticRegression(**best_params_lr, solver='liblinear', n_jobs=-1)

# Define the directory and file path to save the model
model_dir = 'best_models_fea+pca_rec0'
model_file = os.path.join(model_dir, 'lr.pkl')

# If the directory does not exist, create the directory
os.makedirs(model_dir, exist_ok=True)

# Save model
with open(model_file, 'wb') as file:
     pickle.dump(best_model_lr, file)

# %%
# Bayesian Optimization with optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)  # Suppress log messages

# Logistic Regression
def objective_function(trial):
    C = trial.suggest_float('C', 0.1, 10, log=True)
    penalty = trial.suggest_categorical('penalty', ['l1', 'l2'])

    model = LogisticRegression(
        C=C,
        penalty=penalty,
        solver='liblinear',
        n_jobs=-1
    )

    # Using cross_val_score to get the average precision score for each fold
    scores = cross_val_score(model, X_train_final, y_train_oversampled, cv=5, scoring='roc_auc')
    roc_auc = np.mean(scores)
    # Printing intermediate results
    print(f"Trial {trial.number+1}, C: {C}, penalty: {penalty}, ROC-AUC: {roc_auc}")
    return roc_auc


study_lr = optuna.create_study(direction="maximize")
study_lr.optimize(objective_function, n_trials=50)

best_params_lr = study_lr.best_params
print("Best Parameters: ", best_params_lr)
print("Best ROC-AUC Score: ", study_lr.best_value)

# Create and save model
best_model_lr = LogisticRegression(**best_params_lr, solver='liblinear', n_jobs=-1)
with open('best_models/lr.pkl', 'wb') as file:
    pickle.dump(best_model_lr, file)
# Out:
# Trial 1, C: 0.22452475676836395, penalty: l1, ROC-AUC: 0.816816676650045
# Trial 2, C: 6.900103303275947, penalty: l2, ROC-AUC: 0.8210231795893073
# Trial 3, C: 0.1378747537709741, penalty: l1, ROC-AUC: 0.8153500276163583
# Trial 4, C: 0.9905702930395847, penalty: l2, ROC-AUC: 0.8195534188532859
# Trial 5, C: 0.29463612235685416, penalty: l2, ROC-AUC: 0.8176755064943821
# Trial 6, C: 0.3260321052753592, penalty: l2, ROC-AUC: 0.8178507990592288
# Trial 7, C: 4.780133868964029, penalty: l2, ROC-AUC: 0.8208224747887284
# Trial 8, C: 0.7762440222401865, penalty: l2, ROC-AUC: 0.8192645491532279
# Trial 9, C: 2.033937568546728, penalty: l1, ROC-AUC: 0.820477075829593
# Trial 10, C: 0.21195309347095795, penalty: l2, ROC-AUC: 0.8172253468899833
# Trial 11, C: 9.448939850349495, penalty: l1, ROC-AUC: 0.8214422221703603
# Trial 12, C: 8.590315186999643, penalty: l1, ROC-AUC: 0.8214365173827473
# Trial 13, C: 9.420642551304493, penalty: l1, ROC-AUC: 0.8214468897238623
# Trial 14, C: 3.083861415802458, penalty: l1, ROC-AUC: 0.8207918763824384
# Trial 15, C: 2.207681189317139, penalty: l1, ROC-AUC: 0.8205263444498898

    min_samples_split = trial.suggest_int('min_samples_split', 2, 15)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 15)
    criterion = trial.suggest_categorical('criterion', ['gini', 'entropy'])

    model = DecisionTreeClassifier(
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        criterion=criterion
    )

    # Using cross_val_score to get the average precision score for each fold
    scores = cross_val_score(model, X_train_final, y_train_oversampled, cv=5, scoring='roc_auc')
    roc_auc = np.mean(scores)
    # Printing intermediate results
    print(f"Trial {trial.number+1}, max_depth: {max_depth}, min_samples_split: {min_samples_split}, "
          f"min_samples_leaf: {min_samples_leaf}, criterion: {criterion}, ROC-AUC: {roc_auc}")
    return roc_auc

study_dt = optuna.create_study(direction="maximize")
study_dt.optimize(objective_function, n_trials=50)

best_params_dt = study_dt.best_params
print("Best Parameters: ", best_params_dt)
print("Best ROC-AUC Score: ", study_dt.best_value)

# Create and save model
best_model_dt = DecisionTreeClassifier(**best_params_dt)
with open('best_models/dt.pkl', 'wb') as file:
    pickle.dump(best_model_dt, file)
# Out:
# Trial 1, max_depth: 6, min_samples_split: 7, min_samples_leaf: 11, criterion: gini, ROC-AUC: 0.8091764101846017
# Trial 2, max_depth: 38, min_samples_split: 4, min_samples_leaf: 2, criterion: gini, ROC-AUC: 0.8341530075899606
# Trial 3, max_depth: 38, min_samples_split: 15, min_samples_leaf: 11, criterion: gini, ROC-AUC: 0.8551961539359144
# Trial 4, max_depth: 10, min_samples_split: 7, min_samples_leaf: 1, criterion: entropy, ROC-AUC: 0.8360506273969832
# Trial 5, max_depth: 14, min_samples_split: 6, min_samples_leaf: 4, criterion: entropy, ROC-AUC: 0.8449210535186872
# Trial 6, max_depth: 41, min_samples_split: 8, min_samples_leaf: 11, criterion: entropy, ROC-AUC: 0.8578047977263829
# Trial 7, max_depth: 25, min_samples_split: 3, min_samples_leaf: 5, criterion: gini, ROC-AUC: 0.8446272569565995
# Trial 8, max_depth: 8, min_samples_split: 3, min_samples_leaf: 7, criterion: entropy, ROC-AUC: 0.836397582207286
# Trial 9, max_depth: 21, min_samples_split: 14, min_samples_leaf: 8, criterion: entropy, ROC-AUC: 0.8588811874256109
# Trial 10, max_depth: 6, min_samples_split: 9, min_samples_leaf: 3, criterion: entropy, ROC-AUC: 0.7956392084866495
# Trial 11, max_depth: 24, min_samples_split: 15, min_samples_leaf: 15, criterion: entropy, ROC-AUC: 0.8581750903041948
# Trial 12, max_depth: 24, min_samples_split: 15, min_samples_leaf: 15, criterion: entropy, ROC-AUC: 0.8596959348202085
# Trial 13, max_depth: 18, min_samples_split: 12, min_samples_leaf: 15, criterion: entropy, ROC-AUC: 0.8579481953423003
# Trial 14, max_depth: 50, min_samples_split: 12, min_samples_leaf: 8, criterion: entropy, ROC-AUC: 0.854140249610389
# Trial 15, max_depth: 31, min_samples_split: 12, min_samples_leaf: 12, criterion: entropy, ROC-AUC: 0.848579378230012
# Trial 16, max_depth: 18, min_samples_split: 14, min_samples_leaf: 6, criterion: entropy, ROC-AUC: 0.8515401630013407
# Trial 17, max_depth: 29, min_samples_split: 13, min_samples_leaf: 9, criterion: entropy, ROC-AUC: 0.8635062143288706
# Trial 18, max_depth: 32, min_samples_split: 10, min_samples_leaf: 13, criterion: entropy, ROC-AUC: 0.850790242738713
# Trial 19, max_depth: 30, min_samples_split: 11, min_samples_leaf: 10, criterion: gini, ROC-AUC: 0.8538220780466806
# Trial 20, max_depth: 45, min_samples_split: 13, min_samples_leaf: 13, criterion: entropy, ROC-AUC: 0.8544586804826251
# Trial 21, max_depth: 28, min_samples_split: 10, min_samples_leaf: 9, criterion: entropy, ROC-AUC: 0.8624715733026311
# Trial 22, max_depth: 29, min_samples_split: 10, min_samples_leaf: 9, criterion: entropy, ROC-AUC: 0.8613568059412771
# Trial 23, max_depth: 34, min_samples_split: 10, min_samples_leaf: 9, criterion: entropy, ROC-AUC: 0.8598541130222148
# Trial 24, max_depth: 35, min_samples_split: 10, min_samples_leaf: 9, criterion: entropy, ROC-AUC: 0.8612839402449429
# Trial 25, max_depth: 28, min_samples_split: 9, min_samples_leaf: 6, criterion: entropy, ROC-AUC: 0.8541410275359725
# Trial 26, max_depth: 29, min_samples_split: 11, min_samples_leaf: 9, criterion: entropy, ROC-AUC: 0.8623922248931001
# Trial 27, max_depth: 20, min_samples_split: 13, min_samples_leaf: 7, criterion: gini, ROC-AUC: 0.8514597773576981
# Trial 28, max_depth: 26, min_samples_split: 11, min_samples_leaf: 10, criterion: entropy, ROC-AUC: 0.8612803099255524
# Trial 29, max_depth: 1, min_samples_split: 13, min_samples_leaf: 7, criterion: entropy, ROC-AUC: 0.5780998389694042
# Trial 30, max_depth: 42, min_samples_split: 6, min_samples_leaf: 10, criterion: gini, ROC-AUC: 0.8513928757575051
# Trial 31, max_depth: 36, min_samples_split: 8, min_samples_leaf: 12, criterion: entropy, ROC-AUC: 0.8523284609260944
# Trial 32, max_depth: 28, min_samples_split: 11, min_samples_leaf: 9, criterion: entropy, ROC-AUC: 0.8622210812646995
# Trial 33, max_depth: 27, min_samples_split: 11, min_samples_leaf: 8, criterion: entropy, ROC-AUC: 0.8564102364634467
# Trial 34, max_depth: 22, min_samples_split: 11, min_samples_leaf: 9, criterion: entropy, ROC-AUC: 0.8586651834218871
# Trial 35, max_depth: 33, min_samples_split: 12, min_samples_leaf: 10, criterion: gini, ROC-AUC: 0.8554642789537421
# Trial 36, max_depth: 38, min_samples_split: 14, min_samples_leaf: 12, criterion: entropy, ROC-AUC: 0.8544407881942014
# Trial 37, max_depth: 14, min_samples_split: 7, min_samples_leaf: 6, criterion: entropy, ROC-AUC: 0.8526404090851336
# Trial 38, max_depth: 15, min_samples_split: 9, min_samples_leaf: 11, criterion: gini, ROC-AUC: 0.8544472709073982
# Trial 39, max_depth: 41, min_samples_split: 8, min_samples_leaf: 7, criterion: entropy, ROC-AUC: 0.8554533879955709
# Trial 40, max_depth: 37, min_samples_split: 13, min_samples_leaf: 8, criterion: entropy, ROC-AUC: 0.858273886853317
# Trial 41, max_depth: 28, min_samples_split: 5, min_samples_leaf: 5, criterion: entropy, ROC-AUC: 0.8467955948667285
# Trial 42, max_depth: 29, min_samples_split: 10, min_samples_leaf: 9, criterion: entropy, ROC-AUC: 0.8576800703244729
# Trial 43, max_depth: 23, min_samples_split: 11, min_samples_leaf: 9, criterion: entropy, ROC-AUC: 0.8628447182742498
# Trial 44, max_depth: 23, min_samples_split: 11, min_samples_leaf: 10, criterion: entropy, ROC-AUC: 0.8605425771637352
# Trial 45, max_depth: 20, min_samples_split: 2, min_samples_leaf: 11, criterion: entropy, ROC-AUC: 0.8566993654720323
# Trial 46, max_depth: 25, min_samples_split: 12, min_samples_leaf: 9, criterion: entropy, ROC-AUC: 0.8565984944546872
# Trial 47, max_depth: 32, min_samples_split: 9, min_samples_leaf: 7, criterion: entropy, ROC-AUC: 0.8538726432096173
# Trial 48, max_depth: 17, min_samples_split: 14, min_samples_leaf: 8, criterion: entropy, ROC-AUC: 0.857802463949632
# Trial 49, max_depth: 26, min_samples_split: 12, min_samples_leaf: 2, criterion: entropy, ROC-AUC: 0.844066631919324
# Trial 50, max_depth: 23, min_samples_split: 11, min_samples_leaf: 8, criterion: gini, ROC-AUC: 0.8532142588573312
# Best Parameters:  {'max_depth': 29, 'min_samples_split': 13, 'min_samples_leaf': 9, 'criterion': 'entropy'}
# Best ROC-AUC Score:  0.8635062143288706

# %% [markdown]
# ##KNN

# %%
# KNN
def objective_function(trial):
    n_neighbors = trial.suggest_int('n_neighbors', 1, 30)
    weights = trial.suggest_categorical('weights', ['uniform', 'distance'])
    p = trial.suggest_int('p', 1, 5)
    metric = trial.suggest_categorical('metric', ['euclidean', 'manhattan', 'minkowski'])

    model = KNeighborsClassifier(
        n_neighbors=n_neighbors,
        weights=weights,
        p=p,
        metric=metric
    )

    # Using cross_val_score to get the average precision score for each fold
    scores = cross_val_score(model, X_train_final, y_train_oversampled, cv=5, scoring='roc_auc')
    roc_auc = np.mean(scores)
    # Printing intermediate results
    print(f"Trial {trial.number+1}, n_neighbors: {n_neighbors}, weights: {weights}, p: {p}, metric: {metric}, "
          f"ROC-AUC: {roc_auc}")
    return roc_auc


study_knn = optuna.create_study(direction="maximize")
study_knn.optimize(objective_function, n_trials=50)

best_params_knn = study_knn.best_params
print("Best Parameters: ", best_params_knn)
print("Best ROC-AUC Score: ", study_knn.best_value)

# Create and save model
best_model_knn = KNeighborsClassifier(**best_params_knn)
with open('best_models/knn.pkl', 'wb') as file:
    pickle.dump(best_model_knn, file)
# Out:
# Trial 1, n_neighbors: 30, weights: distance, p: 1, metric: manhattan, ROC-AUC: 0.9515007481051029
# Trial 2, n_neighbors: 30, weights: uniform, p: 4, metric: euclidean, ROC-AUC: 0.9132561112537309
# Trial 3, n_neighbors: 17, weights: uniform, p: 3, metric: euclidean, ROC-AUC: 0.9433618313405473
# Trial 4, n_neighbors: 14, weights: uniform, p: 1, metric: euclidean, ROC-AUC: 0.9495875697864076
# Trial 5, n_neighbors: 8, weights: distance, p: 4, metric: minkowski, ROC-AUC: 0.95080528263333
# Trial 6, n_neighbors: 29, weights: distance, p: 5, metric: manhattan, ROC-AUC: 0.9529313532534143
# Trial 7, n_neighbors: 9, weights: distance, p: 1, metric: minkowski, ROC-AUC: 0.9668251041772011
# Trial 8, n_neighbors: 23, weights: uniform, p: 3, metric: minkowski, ROC-AUC: 0.9153004996875331
# Trial 38, n_neighbors: 10, weights: distance, p: 4, metric: euclidean, ROC-AUC: 0.9630441265321892
# Trial 39, n_neighbors: 7, weights: distance, p: 5, metric: manhattan, ROC-AUC: 0.9615002035571945
# Trial 40, n_neighbors: 12, weights: uniform, p: 4, metric: manhattan, ROC-AUC: 0.9609289468702757
# Trial 41, n_neighbors: 16, weights: distance, p: 5, metric: euclidean, ROC-AUC: 0.9603525040127995
# Trial 42, n_neighbors: 14, weights: distance, p: 1, metric: manhattan, ROC-AUC: 0.9693826641876772
# Trial 43, n_neighbors: 15, weights: distance, p: 5, metric: minkowski, ROC-AUC: 0.9448331479277359
# Trial 44, n_neighbors: 13, weights: distance, p: 3, metric: manhattan, ROC-AUC: 0.9697291003809243
# Trial 45, n_neighbors: 10, weights: distance, p: 4, metric: manhattan, ROC-AUC: 0.9682904566682484
# Trial 46, n_neighbors: 8, weights: distance, p: 3, metric: manhattan, ROC-AUC: 0.9647550441991385
# Trial 47, n_neighbors: 12, weights: distance, p: 3, metric: manhattan, ROC-AUC: 0.9694145591366062
# Trial 48, n_neighbors: 13, weights: uniform, p: 5, metric: manhattan, ROC-AUC: 0.96004548271579
# Trial 49, n_neighbors: 10, weights: distance, p: 4, metric: manhattan, ROC-AUC: 0.9682904566682484
# Trial 50, n_neighbors: 1, weights: distance, p: 5, metric: manhattan, ROC-AUC: 0.8835748792270532
# Best Parameters:  {'n_neighbors': 13, 'weights': 'distance', 'p': 3, 'metric': 'manhattan'}
# Best ROC-AUC Score:  0.9697291003809243

# %% [markdown]
# ##Random Forest

# %%
# Random Forest
def objective_function(trial):
    n_estimators = trial.suggest_int('n_estimators', 2, 150)
    max_depth = trial.suggest_int('max_depth', 1, 50)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 15)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 15)

    model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        n_jobs=-1
    )

    # Using cross_val_score to get the average ROC-AUC score for each fold
    scores = cross_val_score(model, X_train_final, y_train_oversampled, cv=5, scoring='roc_auc')
    roc_auc = np.mean(scores)
    # Printing intermediate results
    print(f"Trial {trial.number+1}, n_estimators: {n_estimators}, max_depth: {max_depth}, "
          f"min_samples_split: {min_samples_split}, min_samples_leaf: {min_samples_leaf}, ROC-AUC: {roc_auc}")
    return roc_auc


study_rf = optuna.create_study(direction="maximize")
study_rf.optimize(objective_function, n_trials=50)

best_params_rf = study_rf.best_params
print("Best Parameters: ", best_params_rf)
print("Best ROC-AUC: Score: ", study_rf.best_value)

# Create and save model
best_model_rf = RandomForestClassifier(**best_params_rf, n_jobs=-1)
with open('best_models/rf.pkl', 'wb') as file:
    pickle.dump(best_model_rf, file)
# Out:
# Trial 1, n_estimators: 17, max_depth: 7, min_samples_split: 4, min_samples_leaf: 11, ROC-AUC: 0.910095140298879
# Trial 2, n_estimators: 140, max_depth: 24, min_samples_split: 12, min_samples_leaf: 8, ROC-AUC: 0.9700768331168108
# Trial 3, n_estimators: 23, max_depth: 24, min_samples_split: 14, min_samples_leaf: 4, ROC-AUC: 0.9667556094917293
# Trial 4, n_estimators: 113, max_depth: 38, min_samples_split: 13, min_samples_leaf: 3, ROC-AUC: 0.9770926846471198
# Trial 5, n_estimators: 30, max_depth: 47, min_samples_split: 15, min_samples_leaf: 15, ROC-AUC: 0.9490251295894367
# Trial 6, n_estimators: 77, max_depth: 21, min_samples_split: 13, min_samples_leaf: 3, ROC-AUC: 0.9760030702129701
# Trial 7, n_estimators: 139, max_depth: 37, min_samples_split: 8, min_samples_leaf: 8, ROC-AUC: 0.9689327638918062
# Trial 8, n_estimators: 87, max_depth: 50, min_samples_split: 3, min_samples_leaf: 7, ROC-AUC: 0.9706545725169263
# Trial 9, n_estimators: 54, max_depth: 18, min_samples_split: 8, min_samples_leaf: 2, ROC-AUC: 0.9791884161694424
# Trial 10, n_estimators: 72, max_depth: 1, min_samples_split: 11, min_samples_leaf: 4, ROC-AUC: 0.7904590020251996
# Trial 11, n_estimators: 47, max_depth: 13, min_samples_split: 7, min_samples_leaf: 1, ROC-AUC: 0.9754922324130473
# Trial 12, n_estimators: 105, max_depth: 35, min_samples_split: 9, min_samples_leaf: 1, ROC-AUC: 0.9820392541249504
# Trial 13, n_estimators: 106, max_depth: 34, min_samples_split: 6, min_samples_leaf: 1, ROC-AUC: 0.9843056106586179
# Trial 14, n_estimators: 108, max_depth: 34, min_samples_split: 5, min_samples_leaf: 5, ROC-AUC: 0.9766580835543938
# Trial 15, n_estimators: 110, max_depth: 31, min_samples_split: 10, min_samples_leaf: 1, ROC-AUC: 0.9810097992692686
# Trial 16, n_estimators: 96, max_depth: 43, min_samples_split: 6, min_samples_leaf: 11, ROC-AUC: 0.9624360480343116
# Trial 17, n_estimators: 122, max_depth: 30, min_samples_split: 2, min_samples_leaf: 6, ROC-AUC: 0.973788056767823
# Trial 18, n_estimators: 127, max_depth: 43, min_samples_split: 10, min_samples_leaf: 10, ROC-AUC: 0.9654844790880638
# Trial 19, n_estimators: 93, max_depth: 30, min_samples_split: 6, min_samples_leaf: 15, ROC-AUC: 0.955225196491037
# Trial 20, n_estimators: 64, max_depth: 40, min_samples_split: 9, min_samples_leaf: 1, ROC-AUC: 0.9804585093389966
# Trial 21, n_estimators: 2, max_depth: 15, min_samples_split: 5, min_samples_leaf: 3, ROC-AUC: 0.8895407905279781
# Trial 22, n_estimators: 105, max_depth: 31, min_samples_split: 10, min_samples_leaf: 1, ROC-AUC: 0.9817109695286549
# Trial 23, n_estimators: 100, max_depth: 34, min_samples_split: 9, min_samples_leaf: 2, ROC-AUC: 0.9810704774647924
# Trial 24, n_estimators: 126, max_depth: 30, min_samples_split: 7, min_samples_leaf: 1, ROC-AUC: 0.9830728579170783
# Trial 25, n_estimators: 149, max_depth: 28, min_samples_split: 7, min_samples_leaf: 5, ROC-AUC: 0.9760222590440332
# Trial 26, n_estimators: 124, max_depth: 35, min_samples_split: 7, min_samples_leaf: 2, ROC-AUC: 0.9816845200588112
# Trial 27, n_estimators: 84, max_depth: 40, min_samples_split: 5, min_samples_leaf: 4, ROC-AUC: 0.9783632964337299
# Trial 28, n_estimators: 132, max_depth: 27, min_samples_split: 6, min_samples_leaf: 2, ROC-AUC: 0.9819298259261853
 'max_depth': 34, 'min_samples_split': 6, 'min_samples_leaf': 1}
# Best ROC-AUC: Score:  0.9843056106586179

# %% [markdown]
# ##XgBoost

# %%
# XgBoost
# It requires the target to be 0 and 1, and all features be numerical
# Encode our target
label_encoder = LabelEncoder()
# Fit the encoder and transform the target variable
y_train_oversampled_encoded = label_encoder.fit_transform(y_train_oversampled)


# This suppresses printing logs
optuna.logging.set_verbosity(optuna.logging.WARNING)

def objective_function(trial):
    n_estimators = trial.suggest_int('n_estimators', 2, 150)
    max_depth = trial.suggest_int('max_depth', 1, 50)
    learning_rate = trial.suggest_float('learning_rate', 0.001, 0.9, log=True)
    min_child_weight = trial.suggest_int('min_child_weight', 1, 10)
    subsample = trial.suggest_float('subsample', 0.5, 1.0)
    colsample_bytree = trial.suggest_float('colsample_bytree', 0.5, 1.0)
    gamma = trial.suggest_float('gamma', 0, 1.0)
    reg_alpha = trial.suggest_float('reg_alpha', 0, 1)
    reg_lambda = trial.suggest_float('reg_lambda', 0, 1)

    model = XGBClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        learning_rate=learning_rate,
        min_child_weight=min_child_weight,
        subsample=subsample,
        colsample_bytree=colsample_bytree,
        gamma=gamma,
        reg_alpha=reg_alpha,
        reg_lambda=reg_lambda,
        use_label_encoder=False,
        n_jobs=-1
    )

    # Using cross_val_score to get the average ROC-AUC score for each fold
    scores = cross_val_score(model, X_train_final, y_train_oversampled_encoded, cv=5, scoring='roc_auc')
    roc_auc = np.mean(scores)
    # Printing intermediate results
    print(f"Trial {trial.number+1}, n_estimators: {n_estimators}, max_depth: {max_depth}, learning_rate: {learning_rate},"
          f"min_child_weight: {min_child_weight}, subsample: {subsample}, colsample_bytree: {colsample_bytree}, "
          f"gamma: {gamma}, reg_alpha: {reg_alpha}, reg_lambda: {reg_lambda}, ROC-AUC: {roc_auc}")
    return roc_auc


study_xgb = optuna.create_study(direction="maximize")
study_xgb.optimize(objective_function, n_trials=50)

best_params_xgb = study_xgb.best_params
print("Best Parameters: ", best_params_xgb)
print("Best ROC-AUC Score: ", study_xgb.best_value)

best_model_xgb = XGBClassifier(**best_params_xgb, use_label_encoder=False, n_jobs=-1)
with open('best_models/xgb.pkl', 'wb') as file:
    pickle.dump(best_model_xgb, file)
# Out:
# Trial 1, n_estimators: 134, max_depth: 46, learning_rate: 0.4871879732714302,min_child_weight: 1, subsample: 0.7742272548969249, colsample_bytree: 0.5740215095174981, gamma: 0.6852623553486134, reg_alpha: 0.4528969788615518, reg_lambda: 0.9497646247838009, ROC-AUC: 0.9720828438884869
# Trial 2, n_estimators: 110, max_depth: 9, learning_rate: 0.0012971569472842194,min_child_weight: 7, subsample: 0.7125773000726454, colsample_bytree: 0.6918890610443733, gamma: 0.36248035376814747, reg_alpha: 0.25250469635029404, reg_lambda: 0.8862646124979818, ROC-AUC: 0.9355312324156404
# Trial 3, n_estimators: 31, max_depth: 9, learning_rate: 0.010464227175494457,min_child_weight: 3, subsample: 0.8083355094357882, colsample_bytree: 0.7321142016850231, gamma: 0.6536097715021932, reg_alpha: 0.8135242008573667, reg_lambda: 0.38073711336549043, ROC-AUC: 0.9496931083572544
# Trial 4, n_estimators: 62, max_depth: 41, learning_rate: 0.04700703674534423,min_child_weight: 2, subsample: 0.6799804529036664, colsample_bytree: 0.9759986240565894, gamma: 0.06579042328334395, reg_alpha: 0.3872646567008641, reg_lambda: 0.03990007532598194, ROC-AUC: 0.9795810092806523
# Trial 47, n_estimators: 130, max_depth: 50, learning_rate: 0.1826462022019197,min_child_weight: 3, subsample: 0.5291014325619138, colsample_bytree: 0.6441479005632715, gamma: 0.1900024456740873, reg_alpha: 0.9522685015216827, reg_lambda: 0.9167810498908737, ROC-AUC: 0.982139347216712
# Trial 48, n_estimators: 137, max_depth: 44, learning_rate: 0.11562209823303693,min_child_weight: 1, subsample: 0.6618060461842055, colsample_bytree: 0.590800230227154, gamma: 0.13619122898605335, reg_alpha: 0.8055846138675309, reg_lambda: 0.9592212883312352, ROC-AUC: 0.9842866811360824
# Trial 49, n_estimators: 136, max_depth: 45, learning_rate: 0.13720178050821297,min_child_weight: 3, subsample: 0.6722860777758576, colsample_bytree: 0.6006459767549733, gamma: 0.04028962012421833, reg_alpha: 0.7801556663615434, reg_lambda: 0.968342654902771, ROC-AUC: 0.9843834032169816
# Trial 50, n_estimators: 137, max_depth: 47, learning_rate: 0.0018961855075814152,min_child_weight: 5, subsample: 0.7674574540434924, colsample_bytree: 0.5950411950547678, gamma: 0.03499270380557323, reg_alpha: 0.46609774176555113, reg_lambda: 0.948065897071931, ROC-AUC: 0.9552827629842262
# Best Parameters:  {'n_estimators': 136, 'max_depth': 45, 'learning_rate': 0.13720178050821297, 'min_child_weight': 3, 'subsample': 0.6722860777758576, 'colsample_bytree': 0.6006459767549733, 'gamma': 0.04028962012421833, 'reg_alpha': 0.7801556663615434, 'reg_lambda': 0.968342654902771}
# Best ROC-AUC Score:  0.9843834032169816

# %% [markdown]
# #Model Selection

# %%
# Model selection - Compare Performance
with open('best_models/lr.pkl', 'rb') as file:
    best_model_lr = pickle.load(file)
with open('best_models/dt.pkl', 'rb') as file:
    best_model_dt = pickle.load(file)
with open('best_models/knn.pkl', 'rb') as file:
    best_model_knn = pickle.load(file)
with open('best_models/rf.pkl', 'rb') as file:
    best_model_rf = pickle.load(file)
with open('best_models/xgb.pkl', 'rb') as file:
    best_model_xgb = pickle.load(file)

# %%
def evaluate_models(models, X_train, y_train, X_test, y_test):
    """
    Evaluates multiple models by fitting them on training data, predicting probabilities on test data,
    comparing predicted results with actual results, and computing the ROC AUC score for each.

    Parameters:
    - models: dict, a dictionary of models where keys are model names and values are the model instances.
    - X_train: array-like, training features.
    - y_train: array-like, training target.
    - X_test: array-like, testing features.
    - y_test: array-like, testing target.

    Returns:
    - result_df: DataFrame, a DataFrame containing actual values, predicted probabilities and model comparisons.
    """
    predictions = {'Actual': y_test}
    performances = {}
    print("Testing Performances...Please wait")

    for model_name, model in models.items():
      if model_name == 'XGBoost':
        # Fit and transform the labels in the training data
        y_train = label_encoder.fit_transform(y_train)

        # Transform the labels in the test data
        y_test = label_encoder.transform(y_test)
      else:
        # Fit the model
        model.fit(X_train, y_train)

      # Predict probabilities
      predicted_probs = model.predict_proba(X_test)[:, 1]
      predictions[f'Predicted_Prob_{model_name}'] = predicted_probs

      # Compute ROC AUC score
      roc_auc = roc_auc_score(y_test, predicted_probs)
      performances[model_name] = roc_auc
      print(f"{model_name} ROC AUC: {roc_auc:.4f}")

    # Create a DataFrame from the predictions dictionary
    result_df = pd.DataFrame(predictions)

    # Add a summary of performances at the end of the DataFrame
    performance_summary = pd.DataFrame([performances], index=['ROC AUC Score'])

    return result_df, performance_summary

# Example usage:
models = {
    'Logistic Regression': best_model_lr,
    'Decision Tree': best_model_dt,
    'KNN': best_model_knn,
    'Random Forest': best_model_rf,
    'XGBoost': best_model_xgb
}

# Assuming X_train_final, y_train_oversampled, X_test_final, y_test are already defined and prepared
prediction_results, performance_summary = evaluate_models(models, X_train_final, y_train_oversampled, X_test_final, y_test)
# Out:
# Testing Performances...Please wait
# Logistic Regression ROC AUC: 0.9624
# Decision Tree ROC AUC: 0.5446
# KNN ROC AUC: 0.6916
# Random Forest ROC AUC: 0.3818

# %%
prediction_results.to_csv('prediction.csv', index=False)

prediction_results
# Out:
#                   Actual  Predicted_Prob_Logistic Regression  \
# 9     constant/increased                              0.0058
# 10             decreased                              0.9155
# 20    constant/increased                              0.0012
# 21             decreased                              0.8840
# 31    constant/increased                              0.0008
# 32             decreased                              0.7327
# 42    constant/increased                              0.0019
# 43             decreased                              0.7514
# 53    constant/increased                              0.0004
# 54             decreased                              0.3977
# 64    constant/increased                              0.0021
# 65             decreased                              0.3442
# 75    constant/increased                              0.0073
# 76             decreased                              0.8474
# 86             decreased                              0.0002
# 87             decreased                              0.1917
# 97    constant/increased                              0.0026
# 98             decreased                              0.8519
# 108   constant/increased                              0.0001
# 109            decreased                              0.4753
# 119   constant/increased                              0.0004
# 120            decreased                              0.1745
# 130   constant/increased                              0.0004
# 131            decreased                              0.5056
# 141   constant/increased                              0.0010
# 142            decreased                              0.5773
# 152   constant/increased                              0.0100
# 153            decreased                              0.9652
# 163   constant/increased                              0.0092
# 164            decreased                              0.9490
# 174   constant/increased                              0.0075
# 175            decreased                              0.9313
# 185   constant/increased                              0.0010
# 186            decreased                              0.6253
# 196   constant/increased                              0.0040
# 197            decreased                              0.8785
# 207   constant/increased                              0.0001
# 208            decreased                              0.1161
# 218   constant/increased                              0.0014
# 219            decreased                              0.3200
# 229   constant/increased                              0.0001
# 230            decreased                              0.4009
# 240   constant/increased                              0.0002
# 241            decreased                              0.2062
# 251   constant/increased                              0.0000
# 252            decreased                              0.0023
# 262   constant/increased                              0.0004
# 263            decreased                              0.3480
# 273   constant/increased                              0.0017
# 274            decreased                              0.5240
# 284   constant/increased                              0.0002
# 285            decreased                              0.2732
# 295   constant/increased                              0.0005
# 296            decreased                              0.6710
# 306   constant/increased                              0.0003
# 307            decreased                              0.2808
# 317   constant/increased                              0.0004
# 318            decreased                              0.1684
# 328   constant/increased                              0.0001
# 329            decreased                              0.0626
# 339   constant/increased                              0.0002
# 340            decreased                              0.2637
# 350   constant/increased                              0.0023
# 351            decreased                              0.5860
# 361   constant/increased                              0.0002
# 362            decreased                              0.4392
# 372   constant/increased                              0.0055
# 373            decreased                              0.8989
# 383            decreased                              0.0744
# 384            decreased                              0.9616
# 394   constant/increased                              0.0117
# 395            decreased                              0.4016
# 405   constant/increased                              0.0008
# 406            decreased                              0.2930
# 416   constant/increased                              0.0001
# 417            decreased                              0.5513
# 427   constant/increased                              0.0012
# 428            decreased                              0.6322
# 3684           decreased                              0.1406
# 3694  constant/increased                              0.0005
# 3695           decreased                              0.5830
# 3705  constant/increased                              0.0003
# 3706           decreased                              0.2412
# 3716  constant/increased                              0.0009
# 3717           decreased                              0.0510
# 3727  constant/increased                              0.0255
# 3728           decreased                              0.1487
# 3738  constant/increased                              0.0013
# 3739           decreased                              0.5715
# 3749  constant/increased                              0.0000
# 3750           decreased                              0.0266
# 3760  constant/increased                              0.0078
# 3761           decreased                              0.9461
# 3771  constant/increased                              0.0000
# 3772           decreased                              0.0147
# 3782  constant/increased                              0.0066
# 3783           decreased                              0.3897
# 3793  constant/increased                              0.0001
# 3794           decreased                              0.1667
# 3804  constant/increased                              0.0016
# 3805           decreased                              0.6789
# 3815  constant/increased                              0.0004
# 3816           decreased                              0.1527
# 3826  constant/increased                              0.0004
# 3827           decreased                              0.3399
# 3837  constant/increased                              0.0052
# 3838           decreased                              0.9398
# 3848  constant/increased                              0.0009
# 3849           decreased                              0.4969
# 3859  constant/increased                              0.0002
# 3860           decreased                              0.2620
# 3870  constant/increased                              0.0001
# 3871           decreased                              0.6327
# 3881  constant/increased                              0.0062
# 3882           decreased                              0.4361
# 3892  constant/increased                              0.2081
# 3893           decreased                              0.2359
# 3903  constant/increased                              0.0000
# 3904           decreased                              0.1482
# 3914  constant/increased                              0.0020
# 3915           decreased                              0.7720
# 3925           decreased                              0.0038
# 3926           decreased                              0.6103
# 3936  constant/increased                              0.0020
# 3937           decreased                              0.5036
# 3947  constant/increased                              0.0027
# 3948           decreased                              0.5528
# 3958  constant/increased                              0.0006
# 3959           decreased                              0.3443
# 3969  constant/increased                              0.0004
# 3970           decreased                              0.3380
# 3980  constant/increased                              0.0000
# 3981           decreased                              0.0035
# 3991           decreased                              0.0005
# 3992  constant/increased                              0.2962
# 4002  constant/increased                              0.0000
# 4003           decreased                              0.0799
#
#       Predicted_Prob_Decision Tree  Predicted_Prob_KNN  \
# 9                           0.6667              0.0000
# 10                          1.0000              0.5388
# 20                          0.0000              0.3838
# 21                          0.0000              0.7685
# 31                          0.0000              0.0000
# 32                          0.7778              0.6154
# 42                          0.0000              0.0000
# 43                          0.0000              0.2271
# 53                          0.0000              0.2298
# 54                          0.0000              0.6116
# 64                          0.0000              0.1530
# 65                          1.0000              0.3832
# 75                          0.0000              0.3073
# 76                          0.0000              0.0000
# 86                          0.0000              0.0000
# 87                          0.0000              0.0751
# 97                          0.0000              0.0763
# 98                          0.0000              0.5320
# 108                         0.0000              0.0763
# 109                         0.0000              0.1525
# 119                         0.0000              0.1532
# 120                         0.0000              0.6131
# ...
# 1637                        0.3395
# 1638                        0.2557
# 1648                        0.1676
# 1649                        0.2631
# 1659                        0.2685
# 1660                        0.1132
# 1670                        0.2709
# 1671                        0.3051
# 1681                        0.2600
# 1682                        0.3403
# 1692                        0.2825
# 1693                        0.3026
# 1703                        0.3195
# 1704                        0.3482
# 1714                        0.3050
# 1715                        0.1835
# 1725                        0.1582
# 1726                        0.2507
# 1736                        0.2339
# 1737                        0.2922
# 1747                        0.2186
# 1748                        0.2557
# 3310                        0.2962
# 3320                        0.2708
# 3321                        0.2310
# 3331                        0.2555
# 3332                        0.2759
# 3342                        0.3019
# 3343                        0.2615
# 3353                        0.2719
# 3354                        0.2633
# 3364                        0.2577
# 3365                        0.3037
# 3375                        0.2980
# 3376                        0.2061
# 3386                        0.2940
# 3387                        0.3109
# 3397                        0.3172
# 3398                        0.4992
# 3408                        0.2523
# 3409                        0.2555
# 3419                        0.2671
# 3420                        0.2618
# 3430                        0.2402
# 3431                        0.2291
# 3441                        0.3084
# 3442                        0.2115
# 3452                        0.2912
# 3453                        0.2244
# 3463                        0.3860
# 3464                        0.1578
# 3474                        0.2107
# 3475                        0.2915
# 3485                        0.3060
# 3486                        0.3120
# 3496                        0.2967
# 3497                        0.3899
# 3507                        0.2988
# 3508                        0.2179
# 3518                        0.2598
# 3519                        0.2561
# 3529                        0.2676
# 3530                        0.2011
# 3540                        0.2559
# 3541                        0.2034
# 3551                        0.2535
# 3552                        0.1142
# 3562                        0.2791
# 3563                        0.1864
# 3573                        0.2565
# 3574                        0.1416
# 3584                        0.2558
# 3585                        0.0991
# 3595                        0.2980
# 3596                        0.2845
# 3606                        0.2994
# 3607                        0.2390
# 3617                        0.2421
# 3618                        0.1635
# 3628                        0.2381
# 3629                        0.2042
# 3639                        0.2383
# 3640                        0.4294
# 3650                        0.2323
# 3651                        0.3246
# 3661                        0.2845
# 3662                        0.3037
# 3672                        0.3257
# 3673                        0.2574
# 3683                        0.2875
# 3684                        0.1355
# 3694                        0.2930
# 3695                        0.2519
# 3705                        0.2090
# 3706                        0.1652
# 3716                        0.2852
# 3717                        0.2675
# 3727                        0.2470
# 3728                        0.2698
# 3738                        0.3406
# 3739                        0.2527
# 3749                        0.2941
# 3750                        0.1785
# 3760                        0.3060
# 3761                        0.5472
# 3771                        0.2574
# 3772                        0.1596
# 3782                        0.3224
# 3783                        0.2539
# 3793                        0.2650
# 3794                        0.2125
# 3804                        0.2777
# 3805                        0.3197
# 3815                        0.2581
# 3816                        0.1950
# 3826                        0.2646
# 3827                        0.2181
# 3837                        0.3335
# 3838                        0.4605
# 3848                        0.2241
# 3849                        0.2333
# 3859                        0.2667
# 3860                        0.2360
# 3870                        0.2982
# 3871                        0.2479
# 3881                        0.3090
# 3882                        0.2179
# 3892                        0.2898
# 3893                        0.1832
# 3903                        0.2315
# 3904                        0.1464
# 3914                        0.2704
# 3915                        0.4009
# 3925                        0.2894
# 3926                        0.2978
# 3936                        0.3124
# 3937                        0.3212
# 3947                        0.1701
# 3948                        0.2040
# 3958                        0.2888
# 3959                        0.2014
# 3969                        0.2538
# 3970                        0.2168
# 3980                        0.2215
# 3981                        0.1302
# 3991                        0.2967
# 3992                        0.2037
# 4002                        0.2784
# 4003                        0.1619

# %%
# Define the path to save the file on the desktop
desktop_path = os.path.join(os.path.expanduser('~'), 'Desktop')

# Save the filtered data back to a CSV file on the desktop
prediction_results.to_csv(os.path.join(desktop_path, 'prediction.csv'), index=False)

print("Filtered CSV file has been saved to your desktop.")
# Out:
# Filtered CSV file has been saved to your desktop.
